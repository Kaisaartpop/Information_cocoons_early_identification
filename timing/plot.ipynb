# %%
import numpy as np 
import matplotlib.pyplot as plt
time=[5,10,15,20,25,30,35,40,45]
Accuracy=[0.8928,0.8977,0.9117,0.9159,0.9276,0.9299,0.9323,0.9339,0.9367]
AUC=[0.8774,0.8952,0.9139,0.9245,0.9403,0.9472,0.9521,0.9570,0.9589]
Precision=[0.4791,0.5029,0.5707,0.5913,0.6479,0.6598,0.6712,0.6790,0.6934 ]
Recall=[0.4801,0.5053,0.5724,0.5918,0.6492,0.6579,0.6712,0.6783,0.6900]
F1=[0.4796,0.5041,0.5716,0.5915,0.6485,0.6589,0.6709,0.6787,0.6917]
plt.figure(figsize=(6, 4))

plt.plot(time, Accuracy, label='Accuracy', marker='o')
plt.plot(time, AUC, label='AUC', marker='s')
plt.plot(time, Precision, label='Precision', marker='^')
plt.plot(time, Recall, label='Recall', marker='d')
plt.plot(time, F1, label='F1', marker='*')

plt.xlabel('Time Series Length/hour')
plt.ylabel('Metric Value')
plt.title('Performance Metrics over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()

# 保存为 PDF
output_path = "performance_metrics_over_time.pdf"
plt.savefig(output_path)

plt.show()
